# %%
import os
import pandas as pd
import numpy as np
from ops.imports_ipython import *
import ops.aggregate as agg 
import ops.annotate as anno

# %% [markdown]
# ### Set directory parameters:

# %%
# Set screen directories
aggregate_function_home = "/lab/barcheese01/screens"
aggregate_function_dataset = "denali"
home = os.path.join(aggregate_function_home, aggregate_function_dataset)

# Change working directory to home
os.chdir(home)

# Make directories
os.makedirs("aggregate_4/hdf", exist_ok=True)
os.makedirs("aggregate_4/tif", exist_ok=True)

# %% [markdown]
# ##### load a subset of the data

# %% [markdown]
# The following cell contains crucial variables that need to be set according to your specific experimental setup and data organization. Please review and modify these variables as needed before proceeding with the analysis.
#
# - `population_feature`: The column name that identifies your perturbation groups (e.g., 'gene_symbol_0' for CRISPR screens, 'treatment' for drug screens)
#
# Ensure these variables accurately reflect your experimental setup to guarantee correct data processing and analysis.

# %%
population_feature = 'gene_symbol_0'

# %%
# Load subset of data -- may take ~1 minute
raw_df = agg.load_hdf_subset('merge_3/hdf/merged_final.hdf', n_rows=50000, population_feature=population_feature)
raw_df.to_hdf('aggregate_4/hdf/final_merged_subset.hdf', key='data', mode='w')
pd.Series(raw_df.columns).to_csv('aggregate_4/column_names.csv', index=False)
print(f"Loaded {len(raw_df)} cells with {len(raw_df.columns)} features")
# Out:
# Reading first 50,000 rows from merge_3/hdf/merged_final.hdf
# Unique populations: 4668
# well
# B3    8541
# B1    8464
# B2    8455
# A2    8342
# A1    8336
# A3    7862
# Name: count, dtype: int64
# /tmp/ipykernel_3699372/628507742.py:3: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block0_values] [items->Index(['well', 'tile', 'cell_0', 'site', 'cell_1', 'sgRNA_0', 'gene_symbol_0',
#        'mapped_single_gene'],
#       dtype='object')]
#
#   raw_df.to_hdf('aggregate_4/hdf/final_merged_subset.hdf', key='data', mode='w')
# Loaded 50000 cells with 1683 features

# %% [markdown]
# ##### remove unassigned cells

# %%
clean_df = agg.clean_cell_data(raw_df, population_feature, filter_single_gene=False)
del raw_df
# Out:
# Found 22300 cells with assigned perturbations
# WARNING: 2761 cells have multiple gene assignments

# %% [markdown]
# ##### apply feature transformations

# %% [markdown]
# The following cell contains crucial variables that need to be set according to your specific experimental setup and data organization. Please review and modify these variables as needed before proceeding with the analysis.
#
# - `transformations`: CSV file containing feature transformation specifications. Each row defines a feature pattern and its transformation (e.g., 'log(feature)', 'log(feature-1)'), and should have a feature and transformation column
# - `channels`: List of channels to apply feature transformations to (used to expand feature patterns like 'cell_{channel}_haralick_5_0')
#
# Ensure these variables accurately reflect your experimental setup to guarantee correct data processing and analysis.

# %%
transformations = pd.read_csv('aggregate_4/transformations.csv')
channels = ['dapi', 'coxiv', 'cenpa', 'wga']

# %%
transformed_df = agg.feature_transform(
    clean_df, 
    transformations, 
    channels
)
transformed_df
# Out:
# /lab/barcheese01/mdiberna/OpticalPooledScreens/venv_ops_new/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#       well  tile cell_0          i_0          j_0 site cell_1         i_1  \
# 8       B3   315    430  1479.422074  1478.203880   88    256   99.185629
# 10      B3   155    479  1482.150198  1480.408696   25   1706  669.698795
# 15      B1   114    545  1480.846879  1477.808598   29    252  100.174757
# 20      B1   597    436  1479.251648  1477.600000  155    210  100.600000
# 21      B3   820    606  1482.022972  1478.489591  179   2236  669.363636
# ...    ...   ...    ...          ...          ...  ...    ...         ...
# 49988   A1   704    348  1440.453113  1584.434200  162   1389  660.481481
# 49990   B2  1070    384  1502.393524  1589.405598  252   1582  675.318584
# 49993   B3   507    483  1384.344532  1422.367405  116    150   75.800000
# 49996   A1   434    474  1590.427015  1463.320988  109   1813  698.511364
# 49997   B2   560    556  1475.161832  1591.577863  136    268   98.036145
#
#               j_1  distance  ...  cell_number_neighbors_1  \
# 8       99.862275  0.323345  ...                        0
# 10     671.012048  0.137421  ...                        0
# 15      98.000000  0.187575  ...                        1
# 20     669.250000  0.139653  ...                        0
# 21     671.397727  0.288507  ...                        0
# ...           ...       ...  ...                      ...
# 49988  696.567901  0.105762  ...                        1
# 49990  128.831858  0.401781  ...                        0
# 49993   85.633333  0.323172  ...                        0
# 49996   96.284091  0.176423  ...                        0
# 49997  128.867470  0.126060  ...                        3
#
#        cell_percent_touching_1 cell_first_neighbor_distance  \
# 8                     0.000000                    89.698038
# 10                    0.000000                    56.719075
# 15                    0.233083                    51.744197
# 20                    0.000000                    51.728772
# 21                    0.000000                    64.158910
# ...                        ...                          ...
# 49988                 0.111570                    43.004257
# 49990                 0.000000                    78.885818
# 49993                 0.000000                    98.226727
# 49996                 0.000000                    65.899288
# 49997                 0.584270                    41.324305
#
#       cell_second_neighbor_distance cell_angle_between_neighbors  \
# 8                        102.197643                    30.230493
# 10                        59.884922                    96.311113
# 15                        71.255125                   104.456574
# 20                        53.681662                   168.658189
# 21                        78.609529                   170.469065
# ...                             ...                          ...
# 49988                     47.905117                   142.470998
# 49990                     80.784191                   117.794794
# 49993                    114.014256                    71.078161
# 49996                     70.285586                    92.139094
# 49997                     56.262904                   158.228432
#
#        cytoplasm_number_neighbors_1  cytoplasm_percent_touching_1  \
# 8                               0.0                      0.000000
# 10                              0.0                      0.000000
# 15                              1.0                      0.135371
# 20                              0.0                      0.000000
# 21                              0.0                      0.000000
# ...                             ...                           ...
# 49988                           1.0                      0.074176
# 49990                           0.0                      0.000000
# 49993                           0.0                      0.000000
# 49996                           0.0                      0.000000
# 49997                           3.0                      0.348993
#
#        cytoplasm_first_neighbor_distance  cytoplasm_second_neighbor_distance  \
# 8                              83.031695                           94.507309
# 10                             58.996134                           60.208446
# 15                             52.842614                           76.753835
# 20                             55.227556                           60.331332
# 21                             68.906655                           69.408357
# ...                                  ...                                 ...
# 49988                          38.345890                           52.786206
# 49990                          76.990678                           79.640484
# 49993                         102.666556                          112.253238
# 49996                          62.477779                           63.483686
# 49997                          41.387862                           56.634128
#
#        cytoplasm_angle_between_neighbors
# 8                              36.213157
# 10                             81.681271
# 15                            100.031206
# 20                            160.125690
# 21                            167.824545
# ...                                  ...
# 49988                         142.064492
# 49990                         118.713216
# 49993                          70.672146
# 49996                         105.617294
# 49997                          83.979312
#
# [22300 rows x 1683 columns]

# %% [markdown]
# ##### standardize features

# %% [markdown]
# The following cell contains crucial variables that need to be set according to your specific experimental setup and data organization. Please review and modify these variables as needed before proceeding with the analysis.
#
# - `control_prefix`: Prefix identifying control populations
# - `group_columns`: Columns defining experimental groups (e.g., ['well'] for per-well standardization)
# - `index_columns`: Columns uniquely identifying cells (e.g., ['tile', 'cell_0'])
# - `cat_columns`: Categorical columns to preserve
# - `feature_start`: First column containing measured features
#
#
# We provide a useful function for suggesting these parameters, `suggest_parameters`. Ensure these variables accurately reflect your experimental setup to guarantee correct data processing and analysis.

# %%
agg.suggest_parameters(clean_df, population_feature)
# Out:
# Suggested Parameters:
# --------------------------------------------------
#
# Potential control prefixes found:
#   - 'nontargeting'
#   - 'TNNT2'
#   - 'FNTB'
#   - 'CNTROB'
#   - 'KNTC1'
#   - 'MNT'
#   - 'INTS7'
#   - 'INTS12'
#   - 'INTS10'
#   - 'CCNT1'
#   - 'INTS5'
#   - 'FNTA'
#   - 'NTF4'
#   - 'INTS13'
#   - 'INTS2'
#   - 'INTS8'
#   - 'INTS9'
#   - 'INTS1'
#   - 'TENT4B'
#   - 'BPNT1'
#   - 'B3GNT3'
#   - 'NT5C3B'
#   - 'RINT1'
#   - 'PCNT'
#   - 'ANTXRL'
#   - 'INTS14'
#   - 'INTS6'
#   - 'SPINT1'
#   - 'TRNT1'
#   - 'NT5C'
#   - 'CNTNAP1'
#   - 'ARNTL2'
#   - 'DNTTIP2'
#   - 'ZWINT'
#   - 'INTS3'
#   - 'NTF3'
#   - 'TNNT1'
#
# First few feature columns detected:
#   - 'nucleus_dapi_mean'
#   - 'nucleus_coxiv_mean'
#   - 'nucleus_cenpa_mean'
#   - 'nucleus_wga_mean'
#   - 'nucleus_dapi_std'
#
# Metadata columns detected:
#   - Categorical: well, tile, cell_0, site, cell_1

# %%
control_prefix = 'nontargeting'
group_columns = ['well']
index_columns = ['tile', 'cell_0']
cat_columns = ['gene_symbol_0', 'sgRNA_0']
feature_start = 'nucleus_dapi_mean'

# %%
# Identify features to standardize (all columns after mapped_single_gene)
feature_start_idx = transformed_df.columns.get_loc(feature_start)
target_features = transformed_df.columns[feature_start_idx:].tolist()
# Standardize the data
standardized_df = agg.grouped_standardization(
    transformed_df,
    population_feature=population_feature,
    control_prefix=control_prefix,
    group_columns=group_columns,
    index_columns=index_columns,
    cat_columns=cat_columns,
    target_features=target_features,
    drop_features=False
)
standardized_df
# Out:
#       well  tile  cell_0          i_0          j_0 site cell_1         i_1  \
# 0       B3   315     430  1479.422074  1478.203880   88    256   99.185629
# 1       B3   155     479  1482.150198  1480.408696   25   1706  669.698795
# 2       B1   114     545  1480.846879  1477.808598   29    252  100.174757
# 3       B1   597     436  1479.251648  1477.600000  155    210  100.600000
# 4       B3   820     606  1482.022972  1478.489591  179   2236  669.363636
# ...    ...   ...     ...          ...          ...  ...    ...         ...
# 22295   A1   704     348  1440.453113  1584.434200  162   1389  660.481481
# 22296   B2  1070     384  1502.393524  1589.405598  252   1582  675.318584
# 22297   B3   507     483  1384.344532  1422.367405  116    150   75.800000
# 22298   A1   434     474  1590.427015  1463.320988  109   1813  698.511364
# 22299   B2   560     556  1475.161832  1591.577863  136    268   98.036145
#
#               j_1  distance  ...  cell_number_neighbors_1  \
# 0       99.862275  0.323345  ...                      NaN
# 1      671.012048  0.137421  ...                      NaN
# 2       98.000000  0.187575  ...                      inf
# 3      669.250000  0.139653  ...                      NaN
# 4      671.397727  0.288507  ...                      NaN
# ...           ...       ...  ...                      ...
# 22295  696.567901  0.105762  ...                      inf
# 22296  128.831858  0.401781  ...                      NaN
# 22297   85.633333  0.323172  ...                      NaN
# 22298   96.284091  0.176423  ...                      NaN
# 22299  128.867470  0.126060  ...                      inf
#
#        cell_percent_touching_1 cell_first_neighbor_distance  \
# 0                          NaN                     3.406681
# 1                          NaN                    -0.029332
# 2                          inf                    -0.661367
# 3                          NaN                    -0.662743
# 4                          NaN                     0.745809
# ...                        ...                          ...
# 22295                      inf                    -1.776233
# 22296                      NaN                     1.889269
# 22297                      NaN                     4.295268
# 22298                      NaN                     0.868957
# 22299                      inf                    -1.490859
#
#       cell_second_neighbor_distance cell_angle_between_neighbors  \
# 0                          2.694308                    -2.098684
# 1                         -0.561186                    -0.525710
# 2                          0.095908                    -0.226993
# 3                         -1.147783                     1.121759
# 4                          0.879464                     1.239536
# ...                             ...                          ...
# 22295                     -1.996284                     0.424857
# 22296                      1.349561                     0.456992
# 22297                      3.603465                    -1.126351
# 22298                      0.214981                    -0.573257
# 22299                     -1.019530                     1.215203
#
#        cytoplasm_number_neighbors_1  cytoplasm_percent_touching_1  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               inf                           inf
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# ...                             ...                           ...
# 22295                           inf                           inf
# 22296                           NaN                           NaN
# 22297                           NaN                           NaN
# 22298                           NaN                           NaN
# 22299                           inf                           inf
#
#        cytoplasm_first_neighbor_distance  cytoplasm_second_neighbor_distance  \
# 0                               1.991549                            2.223249
# 1                               0.022799                           -0.640254
# 2                              -0.478528                            0.480550
# 3                              -0.296886                           -0.931127
# 4                               0.834569                            0.127818
# ...                                  ...                                 ...
# 22295                          -2.110957                           -1.577873
# 22296                           1.723343                            1.395336
# 22297                           3.599839                            3.704800
# 22298                           0.422178                           -0.418389
# 22299                          -1.268959                           -1.269979
#
#        cytoplasm_angle_between_neighbors
# 0                              -1.698299
# 1                              -0.748806
# 2                              -0.316765
# 3                               0.867259
# 4                               1.050090
# ...                                  ...
# 22295                           0.363787
# 22296                           0.223386
# 22297                          -0.978705
# 22298                          -0.416659
# 22299                          -0.463787
#
# [22300 rows x 1683 columns]

# %% [markdown]
# ##### add file names

# %% [markdown]
# The following cell contains crucial variables that need to be set according to your specific experimental setup and data organization. Please review and modify these variables as needed before proceeding with the analysis.
#
# - `channel_dict`: Maps fluorescence channels to their corresponding image files
# - `base_ph_file_path`: Points to the "input_ph_tif" folder in your home directory
#
# Ensure these variables accurately reflect your experimental setup to guarantee correct data processing and analysis.

# %%
channel_dict = None
base_ph_file_path = os.path.join(home, "input_ph_tif")

# %%
standardized_df = agg.add_filenames(standardized_df,base_ph_file_path=base_ph_file_path,multichannel_dict=channel_dict)
standardized_df
# Out:
#       well  tile  cell_0          i_0          j_0 site cell_1         i_1  \
# 0       B3   315     430  1479.422074  1478.203880   88    256   99.185629
# 1       B3   155     479  1482.150198  1480.408696   25   1706  669.698795
# 2       B1   114     545  1480.846879  1477.808598   29    252  100.174757
# 3       B1   597     436  1479.251648  1477.600000  155    210  100.600000
# 4       B3   820     606  1482.022972  1478.489591  179   2236  669.363636
# ...    ...   ...     ...          ...          ...  ...    ...         ...
# 22295   A1   704     348  1440.453113  1584.434200  162   1389  660.481481
# 22296   B2  1070     384  1502.393524  1589.405598  252   1582  675.318584
# 22297   B3   507     483  1384.344532  1422.367405  116    150   75.800000
# 22298   A1   434     474  1590.427015  1463.320988  109   1813  698.511364
# 22299   B2   560     556  1475.161832  1591.577863  136    268   98.036145
#
#               j_1  distance  ...  cell_percent_touching_1  \
# 0       99.862275  0.323345  ...                      NaN
# 1      671.012048  0.137421  ...                      NaN
# 2       98.000000  0.187575  ...                      inf
# 3      669.250000  0.139653  ...                      NaN
# 4      671.397727  0.288507  ...                      NaN
# ...           ...       ...  ...                      ...
# 22295  696.567901  0.105762  ...                      inf
# 22296  128.831858  0.401781  ...                      NaN
# 22297   85.633333  0.323172  ...                      NaN
# 22298   96.284091  0.176423  ...                      NaN
# 22299  128.867470  0.126060  ...                      inf
#
#        cell_first_neighbor_distance cell_second_neighbor_distance  \
# 0                          3.406681                      2.694308
# 1                         -0.029332                     -0.561186
# 2                         -0.661367                      0.095908
# 3                         -0.662743                     -1.147783
# 4                          0.745809                      0.879464
# ...                             ...                           ...
# 22295                     -1.776233                     -1.996284
# 22296                      1.889269                      1.349561
# 22297                      4.295268                      3.603465
# 22298                      0.868957                      0.214981
# 22299                     -1.490859                     -1.019530
#
#       cell_angle_between_neighbors cytoplasm_number_neighbors_1  \
# 0                        -2.098684                          NaN
# 1                        -0.525710                          NaN
# 2                        -0.226993                          inf
# 3                         1.121759                          NaN
# 4                         1.239536                          NaN
# ...                            ...                          ...
# 22295                     0.424857                          inf
# 22296                     0.456992                          NaN
# 22297                    -1.126351                          NaN
# 22298                    -0.573257                          NaN
# 22299                     1.215203                          inf
#
#        cytoplasm_percent_touching_1  cytoplasm_first_neighbor_distance  \
# 0                               NaN                           1.991549
# 1                               NaN                           0.022799
# 2                               inf                          -0.478528
# 3                               NaN                          -0.296886
# 4                               NaN                           0.834569
# ...                             ...                                ...
# 22295                           inf                          -2.110957
# 22296                           NaN                           1.723343
# 22297                           NaN                           3.599839
# 22298                           NaN                           0.422178
# 22299                           inf                          -1.268959
#
#        cytoplasm_second_neighbor_distance  cytoplasm_angle_between_neighbors  \
# 0                                2.223249                          -1.698299
# 1                               -0.640254                          -0.748806
# 2                                0.480550                          -0.316765
# 3                               -0.931127                           0.867259
# 4                                0.127818                           1.050090
# ...                                   ...                                ...
# 22295                           -1.577873                           0.363787
# 22296                            1.395336                           0.223386
# 22297                            3.704800                          -0.978705
# 22298                           -0.418389                          -0.416659
# 22299                           -1.269979                          -0.463787
#
#                                                 filename
# 0      /lab/barcheese01/screens/denali/input_ph_tif/2...
# 1      /lab/barcheese01/screens/denali/input_ph_tif/2...
# 2      /lab/barcheese01/screens/denali/input_ph_tif/2...
# 3      /lab/barcheese01/screens/denali/input_ph_tif/2...
# 4      /lab/barcheese01/screens/denali/input_ph_tif/2...
# ...                                                  ...
# 22295  /lab/barcheese01/screens/denali/input_ph_tif/2...
# 22296  /lab/barcheese01/screens/denali/input_ph_tif/2...
# 22297  /lab/barcheese01/screens/denali/input_ph_tif/2...
# 22298  /lab/barcheese01/screens/denali/input_ph_tif/2...
# 22299  /lab/barcheese01/screens/denali/input_ph_tif/2...
#
# [22300 rows x 1684 columns]

# %% [markdown]
# ##### split mitotic and interphase data

# %% [markdown]
# The following cell contains crucial variables that need to be set according to your specific experimental setup and data organization. Please review and modify these variables as needed before proceeding with the analysis.
#
# - `mitotic_threshold_variable`: Column name used to identify mitotic cells (e.g., 'nucleus_dapi_int' for DAPI intensity)
# - `mitotic_threshold`: Numerical threshold to separate mitotic from interphase cells (examine intensity histogram to determine appropriate value)
#
# Ensure these variables accurately reflect your experimental setup to guarantee correct data processing and analysis. Trying different approaches, splitting the data by more than one variable may be best.

# %%
mitotic_threshold_variable = 'nucleus_dapi_median'
mitotic_threshold = 7

percent_mitotic = agg.plot_mitotic_distribution_hist(
    standardized_df, 
    threshold_variable=mitotic_threshold_variable,
    threshold_value=mitotic_threshold
)
# Out:
# Number of mitotic cells: 183
# Total cells: 22,300
# Percent mitotic: 0.82%

# %%
mitotic_threshold_variable = 'nucleus_eccentricity'
mitotic_threshold = 0.8

percent_mitotic = agg.plot_mitotic_distribution_hist(
    standardized_df, 
    threshold_variable=mitotic_threshold_variable,
    threshold_value=mitotic_threshold
)
# Out:
# Number of mitotic cells: 3,929
# Total cells: 22,300
# Percent mitotic: 17.62%

# %%
threshold_variable_x = 'nucleus_eccentricity'
threshold_variable_y = 'nucleus_dapi_median'
threshold_value_x = 0.8
threshold_value_y = 7

agg.plot_mitotic_distribution_scatter(
    standardized_df,
    threshold_variable_x=threshold_variable_x,
    threshold_variable_y=threshold_variable_y,
    threshold_x=threshold_value_x,
    threshold_y=threshold_value_y,
    alpha=0.1
)
# Out:
# Number of mitotic cells: 108
# Total cells: 22,300
# Percent mitotic: 0.48%

# %%
mitotic_threshold_variable = 'nucleus_dapi_median'
mitotic_threshold = 7

conditions = {
    mitotic_threshold_variable: (mitotic_threshold, 'greater'),
}
mitotic_df, interphase_df = agg.split_mitotic_simple(standardized_df, conditions)
print(f"Subsetting {len(mitotic_df)} mitotic cells and {len(interphase_df)} interphase cells")
# Out:
# Subsetting 183 mitotic cells and 22117 interphase cells

# %% [markdown]
# ##### generate montages of mitotic and interphase cells

# %%
plotting_dict = {
    'dapi': {'filename': 'filename', 'channel': 0},
    'coxiv': {'filename': 'filename', 'channel': 1},
    'cenpa': {'filename': 'filename', 'channel': 2},
    'wga': {'filename': 'filename', 'channel': 3}
}

display_ranges = {
    'dapi': [(0, 14000)],
    'coxiv': [(0, 13000)],
    'cenpa': [(0, 6000)],
    'wga': [(350, 2000)]
}

# Default
agg.create_mitotic_cell_montage(
    df=mitotic_df,
    output_dir='aggregate_4/tif',
    output_prefix='mitotic',
    channels=plotting_dict,
    display_ranges=display_ranges
)

# Sorted my median dapi intensity
agg.create_mitotic_cell_montage(
    df=mitotic_df,
    output_dir='aggregate_4/tif',
    output_prefix='mitotic_sorted_nucleus_dapi_median',
    channels=plotting_dict,
    display_ranges=display_ranges,
    selection_params={
        'method': 'sorted',
        'sort_by': 'nucleus_dapi_median',
        'ascending': True
    }
)
# Out:
# Saved dapi montage to aggregate_4/tif/mitotic_dapi.tif
# Saved coxiv montage to aggregate_4/tif/mitotic_coxiv.tif
# Saved cenpa montage to aggregate_4/tif/mitotic_cenpa.tif
# Saved wga montage to aggregate_4/tif/mitotic_wga.tif
# Saved dapi montage to aggregate_4/tif/mitotic_sorted_nucleus_dapi_median_dapi.tif
# Saved coxiv montage to aggregate_4/tif/mitotic_sorted_nucleus_dapi_median_coxiv.tif
# Saved cenpa montage to aggregate_4/tif/mitotic_sorted_nucleus_dapi_median_cenpa.tif
# Saved wga montage to aggregate_4/tif/mitotic_sorted_nucleus_dapi_median_wga.tif

# %% [markdown]
# ##### re-standardize mitotic and interphase data

# %%
# Re-standardize mitotic population
mitotic_standardized_df = agg.grouped_standardization(
    mitotic_df,
    population_feature=population_feature,
    control_prefix=control_prefix,
    group_columns=group_columns,
    index_columns=index_columns,
    cat_columns=cat_columns,
    target_features=target_features,
    drop_features=True
)

# Re-standardize interphase population
interphase_standardized_df = agg.grouped_standardization(
    interphase_df,
    population_feature=population_feature,
    control_prefix=control_prefix,
    group_columns=group_columns,
    index_columns=index_columns,
    cat_columns=cat_columns,
    target_features=target_features,
    drop_features=True
)

# %% [markdown]
# ##### collapse to guide rna

# %%
mitotic_sgrna_df = agg.collapse_to_sgrna(
    mitotic_standardized_df,
    method='median',
    target_features=target_features,
    index_features=[population_feature, 'sgRNA_0'],
    control_prefix=control_prefix
)

interphase_sgrna_df = agg.collapse_to_sgrna(
    interphase_standardized_df,
    method='median',
    target_features=target_features,
    index_features=[population_feature, 'sgRNA_0'],
    control_prefix=control_prefix
)
# Out:
# Multiple control guides not found. Renaming to ensure uniqueness.
# Multiple control guides not found. Renaming to ensure uniqueness.

# %% [markdown]
# ##### collapse to gene

# %%
mitotic_gene_df = agg.collapse_to_gene(
    mitotic_sgrna_df,
    target_features=target_features,
    index_features=[population_feature]
)

interphase_gene_df = agg.collapse_to_gene(
    interphase_sgrna_df,
    target_features=target_features,
    index_features=[population_feature]
)

# %% [markdown]
# ##### return summary of dataset

# %%
summary = pd.DataFrame({
    'Stage': ['Raw Data', 'Mitotic Cells', 'Interphase Cells',
              'Mitotic sgRNAs', 'Interphase sgRNAs',
              'Mitotic Genes', 'Interphase Genes'],
    'Count': [len(clean_df), len(mitotic_df), len(interphase_df),
              len(mitotic_sgrna_df), len(interphase_sgrna_df),
              len(mitotic_gene_df), len(interphase_gene_df)]
})
print("\nAnalysis Summary of Data Subset:")
print(summary)
# Out:
# Analysis Summary of Data Subset:
#                Stage  Count
# 0           Raw Data  22300
# 1      Mitotic Cells    183
# 2   Interphase Cells  22117
# 3     Mitotic sgRNAs    178
# 4  Interphase sgRNAs  10363
# 5      Mitotic Genes    177
# 6   Interphase Genes   4829
